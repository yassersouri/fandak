# %%
from fandak.utils.torch import LRVisualizer

# %%
from torch.optim.lr_scheduler import MultiStepLR, CosineAnnealingLR, CosineAnnealingWarmRestarts

# %%
init_lr = 1e-2

# %%
visualizer1 = LRVisualizer(lr=init_lr)
scheduler1 = CosineAnnealingLR(visualizer1, T_max=20)
visualizer2 = LRVisualizer(lr=init_lr)
scheduler2 = CosineAnnealingWarmRestarts(visualizer2, T)

# %%
for _ in range(100):
    scheduler.step()

# %%
visualizer.plot()
